# %% [markdown]
# ## 노트북 test

# %%
from matplotlib import font_manager, rcParams
# %matplotlib inline
import os
import matplotlib.pyplot as plt

# Path to the uploaded font file
font_path = "/Workspace/Users/juolo@tmapmobility.com/fonts/NanumGothic.ttf"

# Check if the font file exists
assert os.path.exists(font_path), (
    "Please upload NanumGothic.ttf to /Workspace/Users/juolo@tmapmobility.com/fonts/"
)

# Register the font with Matplotlib
font_manager.fontManager.addfont(font_path)

# Set the font family for Matplotlib
rcParams["font.family"] = "NanumGothic"
rcParams["axes.unicode_minus"] = False  # Prevent minus sign from breaking

# %%
# plt.figure(figsize=(6, 4))
# plt.text(0.5, 0.5, "한글 폰트 테스트: 나눔고딕", fontsize=20, ha='center')
# plt.title("테스트")
# plt.xticks([])
# plt.yticks([])
# plt.show()

# plt.show()

from IPython.display import Image

plt.plot([1, 2, 3], [1, 4, 9])
plt.title("테스트")
plt.savefig('temp.png', bbox_inches='tight')
plt.close()

Image('temp.png')  # 이미지가 노트북에 임베드됨
